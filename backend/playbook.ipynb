# %%
import sqlite3
from datetime import datetime
import json

# %%
connection = sqlite3.connect("sixt.db", check_same_thread=False)
cursor = connection.cursor()
cursor.execute('SELECT * FROM vehicles')

print(json.dumps(cursor.fetchall(), indent=3))
# Out:
# [
#    [
#       0,
#       "Brand_3",
#       "dummy",
#       "[]",
#       1,
#       2,
#       "Coupe",
#       "manual",
#       "gas",
#       "available",
#       "True",
#       15.5,
#       22,
#       "Ostbahnhof"
#    ],
#    [
#       1,
#       "Brand_4",
#       "dummy",
#       "[]",
#       1,
#       2,
#       "Coupe",
#       "manual",
#       "gas",
#       "available",
#       "False",
#       15.5,
#       19,
#       "Ostbahnhof"
#    ],
#    [
#       2,
#       "Brand_5",
#       "dummy",
#       "[]",
#       1,
#       2,
#       "Coupe",
#       "manual",
#       "gas",
#       "booked",
#       "True",
#       15.5,
#       23,
#       "Schwabing"
#    ],
#    [
#       3,
#       "Brand_3",
#       "dummy",
#       "[]",
#       1,
#       2,
#       "Coupe",
#       "manual",
#       "gas",
#       "booked",
#       "False",
#       15.5,
#       15,
#       "Schwabing"
#    ],
#    [
#       4,
#       "Brand_1",
#       "dummy",
#       "[]",
# ...

# %%
cursor.execute('SELECT * FROM locations')
print(json.dumps(cursor.fetchall(), indent=3))
